# %%
data = read.csv("Train_Cleaned.csv")

# %%
data$X <-  NULL
data$Field_ID <-  NULL
data$Yield <-  NULL
head(data)
# Out:
#   X0_CLIM_vs X0_CLIM_vpd X0_CLIM_vap X0_CLIM_tmmx X0_CLIM_tmmn X0_CLIM_swe
# 1 1024        934         932        1173         1392         1798
# 2 1023        880         821         924         1116         1630
# 3 1095       1016        1070        1357         1632         1972
# 4  976        777         784         639         1064         2014
# 5 1300       1081        1122        1162         1487         2336
# 6 1188        945         949         921         1365         2200
#   X0_CLIM_srad X0_CLIM_soil X0_CLIM_ro X0_CLIM_pr ⋯ X11_S2_B12 X11_2_B11
# 1 2038         1072         18         2079       ⋯ 125         6
# 2 1951          929         19         1687       ⋯ 126         6
# 3 2137          957         22         2636       ⋯ 135         7
# 4 2588         1300         27         1156       ⋯ 121         6
# 5 2603          710         16         2158       ⋯ 194        66
# 6 2525          716         18         1758       ⋯ 196        62
# ...

# %%
X <-  data
dim(X)
# Out:
# [1] 2977  312

# %%
tail(X)
# Out:
#      X0_CLIM_vs X0_CLIM_vpd X0_CLIM_vap X0_CLIM_tmmx X0_CLIM_tmmn X0_CLIM_swe
# 2972 1138        847         857         756          916         2490
# 2973 1180       1060        1216        1291         1586         2560
# 2974 1181        952        1014         906         1205         2455
# 2975 1111        894         931         797         1196         2239
# 2976 1078        917         987         948         1327         2460
# 2977 1145       1030        1043        1127         1343         1975
#      X0_CLIM_srad X0_CLIM_soil X0_CLIM_ro X0_CLIM_pr ⋯ X11_S2_B12 X11_2_B11
# 2972 2732         667          21          956       ⋯ 26         1
# 2973 2837         727          26         1749       ⋯ 31         2
# 2974 2855         740          22         1200       ⋯ 30         1
# 2975 2452         637          26         1291       ⋯ 30         2
# 2976 3055         898          27         1480       ⋯ 12         1
# ...

# %%
#pca <-  prcomp(scale(X),na.action = NULL)
scale(X)
# Out:
#       X0_CLIM_vs  X0_CLIM_vpd X0_CLIM_vap  X0_CLIM_tmmx X0_CLIM_tmmn
#  [1,] -1.0040804  -0.23650781 -0.391057642  0.34817539   0.098969393
#  [2,] -1.0124841  -0.58512484 -1.021104275 -0.41881267  -0.908930856
#  [3,] -0.4074174   0.29287361  0.392243578  0.91494568   0.975404393
#  [4,] -1.4074583  -1.25007956 -1.231119819 -1.29669057  -1.098825106
#  [5,]  1.3153422   0.71250523  0.687400559  0.31429238   0.445891581
#  [6,]  0.3741272  -0.16549323 -0.294564013 -0.42805349   0.000370456
#  [7,]  0.3237050  -0.04928755 -0.317268396 -0.31408338  -0.240649169
#  [8,]  1.2985347   0.46718213  0.494413302  0.12331544  -0.178568356
#  [9,]  1.8111607   2.55242847  1.516110545  0.98271170   0.683259393
# [10,]  0.6178346   0.47363800  0.301426045  0.28040938  -0.123791169
# [11,]  1.0968458   1.13213685  1.073375073  0.89646404   0.752643831
# [12,]  0.5422013   0.24768252  0.006269064 -0.03377850  -0.043451294
# [13,]  1.0464236   0.85453439  0.755513709  0.66852382   0.394766206
# ...

# %%
pca$rotation
# Out:
#               PC1         PC2          PC3          PC4          PC5
# X0_S2_B5       0.05140064 -0.005694054  0.117221737 -0.201686690  0.08440964
# X0_S2_B4       0.07070892 -0.005454819  0.108529455 -0.223611565  0.07483049
# X0_S2_B3       0.14177792  0.068094066  0.106726817 -0.225900600  0.04037282
# X0_S2_B2       0.14368649  0.041438735  0.100035880 -0.226623396  0.03663738
# X0_CLIM_pr    -0.18030377 -0.069350171 -0.205867607 -0.046620102 -0.03729843
# X0_CLIM_soil  -0.20888680 -0.119841455 -0.131418564  0.042130011  0.05092699
# X1_S2_B5       0.05535657  0.009862047  0.050353062 -0.236303402  0.09813366
# X1_S2_B4       0.04652167  0.010745268  0.049609529 -0.244711509  0.10080767
# X1_S2_B3       0.05280286  0.035303737  0.060200575 -0.262079607  0.09252666
# X1_S2_B2       0.04044024  0.021328967  0.050168582 -0.255957950  0.09190010
# X1_CLIM_pr     0.09050009  0.224009603 -0.018390103 -0.125943584 -0.07237113
# ...

# %%
plot(pca,type="l")
# Out:
# Plot with title “pca”
