# %%
library("tidyverse")
library(ggplot2)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ──────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
dataset =  read.csv("death_rates.csv")

death_rates = dataset

# %%
summary(dataset)
# Out:
#      Sex                 Age          DeathRate
#  Length:62          Min.   :20.00   Min.   : 3.00
#  Class :character   1st Qu.:27.25   1st Qu.: 7.00
#  Mode  :character   Median :35.00   Median :10.00
#                     Mean   :35.00   Mean   :12.65
#                     3rd Qu.:42.75   3rd Qu.:16.00
#                     Max.   :50.00   Max.   :43.00

# %%
ggplot(data = death_rates,aes=()
# Out:
# plot without title
