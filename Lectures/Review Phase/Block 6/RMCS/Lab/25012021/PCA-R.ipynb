# %%
rm(list=ls())

#opening the file
egs=read.table('Droughts.txt',skip=22,header=T)

# %%
# Removing Year and Month
xx=egs[,3:18]

# Replacing the missing values (-999) with -2.33

xx[xx==-999]=-2.33

# calculating the PCA

pp=prcomp(xx,center=T,scale=T)

# %%
#Scree plot

 screeplot(pp,type='l',lwd=3,main='Scree Plot')

#loadings

# Matching the STATISTICA ouput 

mm=array(NA,c(16,16))

for (i in 1:16){
mm[,i]=pp$rotation[,i]*pp$sdev[i]
}

rownames(mm)=names(xx)
colnames(mm)=colnames(pp$rotation)
# Out:
# Plot with title “Scree Plot”

# %%
print('#######################################')
print('##  FIRTS FIVE  LOADINGS              #')
print('#######################################')

print(mm[,1:5])


# Explained variance

ev=round(pp$sdev^2/sum(pp$sdev^2)*100,2)



print('#########################################')
print('##  EXPLAINED VARIANCE (IN %)           #')
print('#########################################')

print(ev)
# Out:
# [1] "#######################################"
# [1] "##  FIRTS FIVE  LOADINGS              #"
# [1] "#######################################"
#                PC1         PC2         PC3          PC4         PC5
# Cld    -0.88990359  0.05824322 -0.32869555 -0.015646186  0.01385704
# Pet    -0.80375390 -0.17721201  0.39411155 -0.043724006  0.10231028
# Pre    -0.81617540  0.13056000 -0.43542269  0.033778383  0.03032685
# Tmn    -0.97954976 -0.12436259  0.07818886 -0.047216994  0.01072712
# Tmp    -0.95471865 -0.18231202  0.20117924 -0.053604089  0.01809055
# Tmx    -0.86629169 -0.26442998  0.38478975 -0.060917560  0.02881411
# Vap    -0.94012802 -0.12794114 -0.01436509 -0.027904887 -0.02887680
# Wet    -0.89076760  0.04821107 -0.33515996  0.032535943  0.04277678
# spei01 -0.11181025  0.34574881 -0.85126439  0.044342498  0.02697753
# MEI     0.11364035 -0.93238369 -0.13833673 -0.004680840 -0.03161853
# NINO34  0.34414833 -0.84680303 -0.19804270 -0.017863578 -0.07454770
# QBO    -0.09764358  0.04718511 -0.09565658 -0.482088358 -0.81067814
# SOI    -0.06198041  0.83320683  0.16414823  0.005430383  0.01156279
# AO      0.11529223  0.14525327  0.04791095 -0.779218594  0.14068662
# ONI     0.08920166 -0.93656378 -0.15247675  0.016080255  0.00862926
# WP      0.22273478 -0.12231153 -0.19560140 -0.519208729  0.53806991
# [1] "#########################################"
# [1] "##  EXPLAINED VARIANCE (IN %)           #"
# [1] "#########################################"
#  [1] 41.44 21.90 10.27  7.04  6.18  4.90  2.71  1.91  1.39  0.78  0.74  0.44
# [13]  0.19  0.07  0.03  0.00
