# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt

# %%
# Read Data
companies = ['GOOGL', 'AAPL','AMZN','NKE']
provider = "yahoo"
s_date  = '2015/01/01'
e_date = '2019/12/31'
dataf = data.DataReader(companies, 'yahoo', start=s_date, end=e_date)
dataf.head(10)
# Out:
# Attributes   Adj Close                                         Close  \
# Symbols          GOOGL       AAPL        AMZN        NKE       GOOGL
# Date
# 2015-01-02  529.549988  24.861401  308.519989  44.347309  529.549988
# 2015-01-05  519.460022  24.161013  302.190002  43.633312  519.460022
# 2015-01-06  506.640015  24.163294  295.290009  43.376633  506.640015
# 2015-01-07  505.149994  24.502111  298.420013  44.272652  505.149994
# 2015-01-08  506.910004  25.443539  300.459991  45.294640  506.910004
# 2015-01-09  500.720001  25.470825  296.929993  44.795315  500.720001
# 2015-01-12  497.059998  24.843210  291.410004  44.734642  497.059998
# 2015-01-13  501.799988  25.063780  294.739990  44.337986  501.799988
# 2015-01-14  505.929993  24.968279  293.269989  43.731304  505.929993
# 2015-01-15  504.010010  24.290628  286.950012  43.311310  504.010010
#
# Attributes                                          High             ...  \
# Symbols          AAPL        AMZN        NKE       GOOGL       AAPL  ...
# Date                                                                 ...
# 2015-01-02  27.332500  308.519989  47.514999  535.799988  27.860001  ...
# 2015-01-05  26.562500  302.190002  46.750000  527.989990  27.162500  ...
# 2015-01-06  26.565001  295.290009  46.474998  521.210022  26.857500  ...
# 2015-01-07  26.937500  298.420013  47.435001  511.489990  27.049999  ...
# 2015-01-08  27.972500  300.459991  48.529999  507.500000  28.037500  ...
# 2015-01-09  28.002501  296.929993  47.994999  508.600006  28.312500  ...
# 2015-01-12  27.312500  291.410004  47.930000  500.279999  28.157499  ...
# 2015-01-13  27.555000  294.739990  47.505001  508.600006  28.200001  ...
# 2015-01-14  27.450001  293.269989  46.855000  508.260010  27.622499  ...
# 2015-01-15  26.705000  286.950012  46.404999  509.750000  27.514999  ...
#
# Attributes         Low                   Open                         \
# Symbols           AMZN        NKE       GOOGL       AAPL        AMZN
# Date
# 2015-01-02  306.959991  47.055000  532.599976  27.847500  312.579987
# 2015-01-05  300.850006  46.564999  527.150024  27.072500  307.010010
# 2015-01-06  292.380005  46.035000  520.500000  26.635000  302.239990
# 2015-01-07  295.329987  46.549999  510.950012  26.799999  297.500000
# 2015-01-08  296.109985  47.810001  501.510010  27.307501  300.320007
# 2015-01-09  296.679993  47.799999  508.179993  28.167500  301.480011
# 2015-01-12  289.279999  47.615002  499.239990  28.150000  297.559998
# 2015-01-13  293.230011  47.314999  502.570007  27.857500  297.480011
# 2015-01-14  286.500000  46.455002  500.420013  27.260000  291.929993
# 2015-01-15  286.820007  46.285000  508.890015  27.500000  294.000000
#
# Attributes                Volume
# Symbols           NKE      GOOGL         AAPL       AMZN        NKE
# Date
# 2015-01-02  48.275002  1324000.0  212818400.0  2783200.0  4985800.0
# 2015-01-05  47.255001  2059100.0  257142000.0  2774200.0  6889200.0
# 2015-01-06  46.945000  2722800.0  263188400.0  3519000.0  7576000.0
# 2015-01-07  46.805000  2345900.0  160423600.0  2640300.0  7256000.0
# 2015-01-08  47.830002  3652700.0  237458000.0  3088400.0  5978200.0
# 2015-01-09  48.465000  2100000.0  214798000.0  2592400.0  4689000.0
# 2015-01-12  47.955002  2856900.0  198603200.0  3421400.0  5630800.0
# 2015-01-13  48.169998  3047900.0  268367600.0  4136400.0  6182200.0
# 2015-01-14  46.689999  2640000.0  195826400.0  5538700.0  6750400.0
# 2015-01-15  47.314999  2553400.0  240056000.0  4419200.0  4235000.0
#
# [10 rows x 24 columns]

# %%
# Closing price
df =  test['Adj Close']
df.head()
# Out:
# Symbols          GOOGL       AAPL        AMZN        NKE
# Date
# 2015-01-02  529.549988  24.861401  308.519989  44.347309
# 2015-01-05  519.460022  24.161013  302.190002  43.633312
# 2015-01-06  506.640015  24.163294  295.290009  43.376633
# 2015-01-07  505.149994  24.502111  298.420013  44.272652
# 2015-01-08  506.910004  25.443539  300.459991  45.294640

# %% [markdown]
# ### Question (1a)

# %%
# Yearly returns for individual companies
ind_er  =  df.resample('Y').last().pct_change().mean()
ind_er.head()
# Out:
# Symbols
# GOOGL    0.155401
# AAPL     0.361281
# AMZN     0.295903
# NKE      0.162404
# dtype: float64

# %% [markdown]
# ### Question (1b)

# %%
# Portfolio returns
w  = [0.1,0.2,0.5,0.2] 
port_er  =  (w*ind_er).sum()
port_er
# Out:
# 0.26822875735348084

# %% [markdown]
# ### Qustion (2a)

# %%
# 1. Define the necessary arrays
p_ret  = [] #Define an array for portfolio returns
p_vol = [] #Define an empty array for portfolio volatity
p_weights  = [] #Define an empty array 

num_assets  = len(df.columns)
num_portfolios  =  10000
#  2. Covariance Matrix
test2  =  df.pct_change().apply(lambda x:np.log(1+x)) #Log of Percentage of change
cov_matrix =  test2.cov() #Covariance
cov_matrix
# Out:
# Symbols     GOOGL      AAPL      AMZN       NKE
# Symbols
# GOOGL    0.000221  0.000122  0.000176  0.000085
# AAPL     0.000122  0.000246  0.000142  0.000084
# AMZN     0.000176  0.000142  0.000333  0.000092
# NKE      0.000085  0.000084  0.000092  0.000219

# %% [markdown]
# ### Question (2b)

# %%
# Calculate the Return and Risk (volatility)
for portfolio in range(num_portfolios):
    # a get the random numners for the weights
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    # b Return are the product of individual expected returns of the assets and its weights
    ind_er =  df.resample('Y').last().pct_change().mean()
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)
data = {'Returns':p_ret, 'Volatility':p_vol}

# %%
for counter, symbol in enumerate(df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

portfolios  = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  GOOGL weight  AAPL weight  AMZN weight  NKE weight
# 0  0.229022    0.192290      0.420698     0.307782     0.062570    0.208949
# 1  0.266932    0.204124      0.234025     0.325121     0.310924    0.129931
# 2  0.244894    0.189327      0.123607     0.325705     0.139180    0.411508
# 3  0.253680    0.197394      0.330247     0.361853     0.161980    0.145920
# 4  0.291963    0.210923      0.221103     0.495712     0.243605    0.039580

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns         0.212531
# Volatility      0.186545
# GOOGL weight    0.320996
# AAPL weight     0.244329
# AMZN weight     0.028342
# NKE weight      0.406334
# Name: 3670, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[10,8])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.show()

# %% [markdown]
# ### Question (2c) Optimal Risky Portfolio

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns         0.328601
# Volatility      0.219511
# GOOGL weight    0.006411
# AAPL weight     0.752196
# AMZN weight     0.124697
# NKE weight      0.116696
# Name: 1376, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(10, 8))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
plt.show()
